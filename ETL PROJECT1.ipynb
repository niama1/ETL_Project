# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
player_file =  './resources/player_data.csv'
player_data = pd.read_csv(player_file)
player_data
# Out:
#                      name  year_start  year_end position  height  weight  \
# 0          Alaa Abdelnaby        1991      1995      F-C  10-Jun   240.0
# 1         Zaid Abdul-Aziz        1969      1978      C-F   9-Jun   235.0
# 2     Kareem Abdul-Jabbar        1970      1989        C   2-Jul   225.0
# 3      Mahmoud Abdul-Rauf        1991      2001        G   1-Jun   162.0
# 4       Tariq Abdul-Wahad        1998      2003        F   6-Jun   223.0
# ...                   ...         ...       ...      ...     ...     ...
# 4545           Ante Zizic        2018      2018      F-C  11-Jun   250.0
# 4546             Jim Zoet        1983      1983        C   1-Jul   240.0
# 4547            Bill Zopf        1971      1971        G   1-Jun   170.0
# 4548          Ivica Zubac        2017      2018        C   1-Jul   265.0
# 4549           Matt Zunic        1949      1949      G-F   3-Jun   195.0
#
#      birth_date                                college
# ...

# %%
players ='./resources/players.csv'
players_df = pd.read_csv(players)
players_df
# Out:
#       Unnamed: 0             Player  height  weight  \
# 0              0    Curly Armstrong   180.0    77.0
# 1              1       Cliff Barker   188.0    83.0
# 2              2      Leo Barnhorst   193.0    86.0
# 3              3         Ed Bartels   196.0    88.0
# 4              4        Ralph Beard   178.0    79.0
# ...          ...                ...     ...     ...
# 3917        3917      Troy Williams   198.0    97.0
# 3918        3918       Kyle Wiltjer   208.0   108.0
# 3919        3919  Stephen Zimmerman   213.0   108.0
# 3920        3920        Paul Zipser   203.0    97.0
# 3921        3921        Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 0                  Indiana University  1918.0             NaN
# 1              University of Kentucky  1921.0        Yorktown
# 2            University of Notre Dame  1924.0             NaN
# 3     North Carolina State University  1925.0             NaN
# ...

# %%
player_data['college'].value_counts()
# Out:
# University of Kentucky                                      99
# University of California, Los Angeles                       91
# University of North Carolina                                87
# University of Kansas                                        72
# Duke University                                             71
#                                                             ..
# St. Francis College                                          1
# Montana State University                                     1
# California Polytechnic State University, San Luis Obispo     1
# Ashland University                                           1
# California Western Uiversity                                 1
# Name: college, Length: 473, dtype: int64

# %%
player_data= player_data.rename(columns={'name': 'Player'})
players_df= players_df.rename(columns={'birth_state': 'State'})

Player_Profile_Dirty = pd.merge(player_data, players_df, how='left', on=["Player","Player"])
Player_Profile_Dirty
# Out:
#                    Player  year_start  year_end position height_x  weight_x  \
# 0          Alaa Abdelnaby        1991      1995      F-C   10-Jun     240.0
# 1         Zaid Abdul-Aziz        1969      1978      C-F    9-Jun     235.0
# 2     Kareem Abdul-Jabbar        1970      1989        C    2-Jul     225.0
# 3      Mahmoud Abdul-Rauf        1991      2001        G    1-Jun     162.0
# 4       Tariq Abdul-Wahad        1998      2003        F    6-Jun     223.0
# ...                   ...         ...       ...      ...      ...       ...
# 4545           Ante Zizic        2018      2018      F-C   11-Jun     250.0
# 4546             Jim Zoet        1983      1983        C    1-Jul     240.0
# 4547            Bill Zopf        1971      1971        G    1-Jun     170.0
# 4548          Ivica Zubac        2017      2018        C    1-Jul     265.0
# 4549           Matt Zunic        1949      1949      G-F    3-Jun     195.0
#
# ...

# %%
new = ['Player',
  'college',
  'State']
player_profile = Player_Profile_Dirty[new]
player_profile
# Out:
#                    Player                                college  \
# 0          Alaa Abdelnaby                        Duke University
# 1         Zaid Abdul-Aziz                  Iowa State University
# 2     Kareem Abdul-Jabbar  University of California, Los Angeles
# 3      Mahmoud Abdul-Rauf             Louisiana State University
# 4       Tariq Abdul-Wahad              San Jose State University
# ...                   ...                                    ...
# 4545           Ante Zizic                                    NaN
# 4546             Jim Zoet                  Kent State University
# 4547            Bill Zopf                    Duquesne University
# 4548          Ivica Zubac                                    NaN
# 4549           Matt Zunic           George Washington University
#
#                        State
# 0                      Egypt
# 1                   New York
# 2                        NaN
# 3                   Delaware
# 4                     France
# ...

# %%
LL ='./resources/50_Slat_Lng.csv'
LL_df = pd.read_csv(LL)
LL_df
# Out:
#           Place Name   Latitude   Longitude
# 0          Wisconsin  44.500000  -89.500000
# 1      West Virginia  39.000000  -80.500000
# 2            Vermont  44.000000  -72.699997
# 3              Texas  31.000000 -100.000000
# 4       South Dakota  44.500000 -100.000000
# 5       Rhode Island  41.700001  -71.500000
# 6             Oregon  44.000000 -120.500000
# 7           New York  43.000000  -75.000000
# 8      New Hampshire  44.000000  -71.500000
# 9           Nebraska  41.500000 -100.000000
# 10            Kansas  38.500000  -98.000000
# 11       Mississippi  33.000000  -90.000000
# 12          Illinois  40.000000  -89.000000
# 13          Delaware  39.000000  -75.500000
# 14       Connecticut  41.599998  -72.699997
# 15          Arkansas  34.799999  -92.199997
# 16           Indiana  40.273502  -86.126976
# 17    Missouri State  38.573936  -92.603760
# 18           Florida  27.994402  -81.760254
# 19            Nevada  39.876019 -117.224121
# ...

# %%
ll_df= LL_df.rename(columns={'Place Name': 'State'})
clean = pd.merge(player_profile, ll_df, how='left', on=["State","State"])
clean.dropna()
# Out:
#                    Player                          college       State  \
# 1         Zaid Abdul-Aziz            Iowa State University    New York
# 3      Mahmoud Abdul-Rauf       Louisiana State University    Delaware
# 5     Shareef Abdur-Rahim         University of California     Georgia
# 6           Tom Abernethy               Indiana University     Indiana
# 10             Alex Acker            Pepperdine University  California
# ...                   ...                              ...         ...
# 4536          Luke Zeller         University of Notre Dame        Iowa
# 4537         Tyler Zeller     University of North Carolina  California
# 4538            Tony Zeno         Arizona State University   Louisiana
# 4542    Derrick Zimmerman     Mississippi State University   Louisiana
# 4543    Stephen Zimmerman  University of Nevada, Las Vegas   Tennessee
#
#        Latitude   Longitude
# 1     43.000000  -75.000000
# 3     39.000000  -75.500000
# ...
